# %%
import pandas as pd

# %%
dataframe = pd.read_csv('grades.csv', sep='\t')

# %%
dataframe
# Out:
#     stdNo               stdName   BirthDate                      email  \
# 0     701         Rosa C. Olsen  07/06/1996  l0701@aln.iseg.ulisboa.pt
# 1     798     Clarence Sheridan  03/01/1996  l0798@aln.iseg.ulisboa.pt
# 2     854      Jaclyn T. Glover  20/09/1995  l0854@aln.iseg.ulisboa.pt
# 3     663    Catherine U. Buggs  09/12/1995  l0663@aln.iseg.ulisboa.pt
# 4     921      James E. Watkins  08/08/1999  l0921@aln.iseg.ulisboa.pt
# 5     890        Babara T. Best  09/04/1998  l0890@aln.iseg.ulisboa.pt
# 6     666  Carlton L. Dickerson  24/07/1997  l0666@aln.iseg.ulisboa.pt
# 7     843      Kerry K. Ratliff  30/05/2000  l0843@aln.iseg.ulisboa.pt
# 8     991     Carrie D. Johnson  21/08/1998  l0991@aln.iseg.ulisboa.pt
# 9     798          Harold Brown  18/01/1999  l0798@aln.iseg.ulisboa.pt
# 10    713      Camilla N. Welch  05/08/1997  l0713@aln.iseg.ulisboa.pt
# 11    755     Chelsey K. Kinley  29/05/2000  l0755@aln.iseg.ulisboa.pt
# ...

# %% [markdown]
# dataframe.iloc[linha, coluna] - usa índices
# dataframe.iloc[linha, coluna] - usa o nome das colunas

# %%
dataframe.iloc[3:5,2:6]
# Out:
#     BirthDate                      email  Test 1  Test 2
# 3  09/12/1995  l0663@aln.iseg.ulisboa.pt    15.0     6.8
# 4  08/08/1999  l0921@aln.iseg.ulisboa.pt    11.0     8.0

# %%
dataframe.loc[3, 'stdName':'email']
# Out:
# stdName             Catherine U. Buggs
# BirthDate                   09/12/1995
# email        l0663@aln.iseg.ulisboa.pt
# Name: 3, dtype: object

# %%
my_w = pd.ExcelWriter('novo_excel.xlsx', engine='xlsxwriter')

# %%
dataframe.to_excel(my_w,sheet_name='notas', index=False)

# %%
my_w.close()
